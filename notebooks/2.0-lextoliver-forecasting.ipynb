# %% [markdown]
# # Forecasting Time Series Analysis

# %%
import pandas as pd
import plotly.offline as py
import plotly.graph_objs as go
import ipywidgets as widgets
from IPython.display import display

py.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('../data/processed/forecasting_data.csv')
df['DATA'] = pd.to_datetime(df['DATA'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5033 entries, 0 to 5032
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   DATA               5033 non-null   datetime64[ns]
#  1   VALOR_REEMBOLSADO  5033 non-null   float64
#  2   COUNT              5033 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 118.1 KB

# %%
# Check if all years have 365 days
df.groupby(df['DATA'].dt.year)['DATA'].count()
# Out:
# DATA
# 2009    285
# 2010    365
# 2011    365
# 2012    366
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    365
# Name: DATA, dtype: int64

# %% [markdown]
# ## Fixing year 2009
# We can see above that in 2009, some dates are missing to compose the time series. To solve this, we need to find which dates are missing and define an approach.

# %%
# Find the missing days of 2009
missing_days = pd.date_range(start='2009-01-01', end='2009-12-31').difference(df[df['DATA'].dt.year == 2009]['DATA'])
missing_days
# Out:
# DatetimeIndex(['2009-01-01', '2009-01-02', '2009-01-03', '2009-01-04',
#                '2009-01-05', '2009-01-06', '2009-01-07', '2009-01-08',
#                '2009-01-09', '2009-01-10', '2009-01-11', '2009-01-12',
#                '2009-01-13', '2009-01-14', '2009-01-15', '2009-01-16',
#                '2009-01-17', '2009-01-18', '2009-01-19', '2009-01-20',
#                '2009-01-21', '2009-01-22', '2009-01-23', '2009-01-24',
#                '2009-01-25', '2009-01-27', '2009-01-28', '2009-01-29',
#                '2009-01-30', '2009-01-31', '2009-02-01', '2009-02-02',
#                '2009-02-03', '2009-02-04', '2009-02-05', '2009-02-06',
#                '2009-02-07', '2009-02-08', '2009-02-09', '2009-02-10',
#                '2009-02-11', '2009-02-12', '2009-02-13', '2009-02-14',
#                '2009-02-15', '2009-02-16', '2009-02-17', '2009-02-18',
#                '2009-02-19', '2009-02-20', '2009-02-21', '2009-02-22',
#                '2009-02-23', '2009-02-24', '2009-02-25', '2009-02-26',
#                '2009-02-27', '2009-03-01', '2009-03-02', '2009-03-03',
#                '2009-03-04', '2009-03-05', '2009-03-06', '2009-03-07',
#                '2009-03-08', '2009-03-09', '2009-03-10', '2009-03-11',
#                '2009-03-12', '2009-03-14', '2009-03-15', '2009-03-16',
#                '2009-03-20', '2009-03-22', '2009-03-23', '2009-03-24',
#                '2009-03-25', '2009-03-29', '2009-03-30', '2009-03-31'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# We can see above that up intil April, most of the dates are missing. Since the missing dates are centered in those first months, the approach defined was to remove the few dates from these months and begin the times series from April.

# %%
# Drop the rows where the data is less than 2009-04-01
df = df[df['DATA'] >= '2009-04-01']

# %% [markdown]
# ## Ploting the data

# %%
# Chart default layout
default_layout = dict(
    titlefont=dict(size=18, color="darkblue"),
    tickfont=dict(size=14, color="black"),
    showgrid=True,
    zeroline=True,
    showline=True,
    mirror=True,
    gridcolor="lightgrey",
    gridwidth=1,
    zerolinecolor="grey",
    zerolinewidth=2,
    linecolor="black",
    linewidth=2,
)

# %%
# Define x and y axis layout
xaxis_layout = default_layout.copy()
xaxis_layout["title"] = "Data"

yaxis_layout = default_layout.copy()
yaxis_layout["title"] = "Valor reembolsado (R$)"

# %%
# Plot the data
trace = go.Scatter(
    x=df["DATA"],
    y=df["VALOR_REEMBOLSADO"],
    mode="lines",
    marker=dict(size=10, color="blue", symbol="circle"),
    line=dict(width=2, color="blue"),
)

# Set chart layout
layout = go.Layout(
    title="Reimbursement by Year",
    titlefont=dict(size=24, color="darkblue"),
    xaxis=xaxis_layout,
    yaxis=yaxis_layout,
    hovermode="closest",
    plot_bgcolor="white",
)

py.iplot({"data": [trace], "layout": layout})
# Out:
# <div>                            <div id="6659d0bc-9287-45ae-8249-691628f5a7c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
:00","2009-07-25T00:00:00","2009-07-26T00:00:00","2009-07-27T00:00:00","2009-07-28T00:00:00","2009-07-29T00:00:00","2009-07-30T00:00:00","2009-07-31T00:00:00","2009-08-01T00:00:00","2009-08-02T00:00:00","2009-08-03T00:00:00","2009-08-04T00:00:00","2009-08-05T00:00:00","2009-08-06T00:00:00","2009-08-07T00:00:00","2009-08-08T00:00:00","2009-08-09T00:00:00","2009-08-10T00:00:00","2009-08-11T00:00:00","2009-08-12T00:00:00","2009-08-13T00:00:00","2009-08-14T00:00:00","2009-08-15T00:00:00","2009-08-16T00:00:00","2009-08-17T00:00:00","2009-08-18T00:00:00","2009-08-19T00:00:00","2009-08-20T00:00:00","2009-08-21T00:00:00","2009-08-22T00:00:00","2009-08-23T00:00:00","2009-08-24T00:00:00","2009-08-25T00:00:00","2009-08-26T00:00:00","2009-08-27T00:00:00","2009-08-28T00:00:00","2009-08-29T00:00:00","2009-08-30T00:00:00","2009-08-31T00:0 ...

# %% [markdown]
# ## Checking stationarity of the time series
# A time series is stationary when its statistical properties, like its mean and variance, do not change over time.
# ![stationary series](https://miro.medium.com/v2/resize:fit:720/format:webp/0*Dyml4bSlkE5WHdcc)

# %% [markdown]
# One way to check if a time series is stationary is by the [Dickey-Fuller Test](https://medium.com/@ritusantra/tests-for-stationarity-in-time-series-dickey-fuller-test-augmented-dickey-fuller-adf-test-d2e92e214360).

# %%
df['DATA'] = df['DATA'].dt.strftime('%Y-%m-%d')
df.values
# Out:
# array([['2009-04-01', 50218.99, 45],
#        ['2009-04-02', 24003.67, 50],
#        ['2009-04-03', 9656.97, 52],
#        ...,
#        ['2022-12-29', 23237.61, 18],
#        ['2022-12-30', 155183.29, 14],
#        ['2022-12-31', 17113.68, 7]], dtype=object)

# %%
# from statsmodels.tsa.stattools import adfuller
# X = df.values
# result = adfuller(X)
# print('ADF Statistic: %f' % result[0])
# print('p-value: %f' % result[1])
# print('Critical Values:')
# for key, value in result[4].items():
# 	print('\t%s: %.3f' % (key, value))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 3
#       1 from statsmodels.tsa.stattools import adfuller
#       2 X = df.values
# ----> 3 result = adfuller(X)
#       4 print('ADF Statistic: %f' % result[0])
#       5 print('p-value: %f' % result[1])
#
# File ~/Documents/Learning/Alura/CEAPS/env/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:263, in adfuller(x, maxlag, regression, autolag, store, regresults)
#     168 def adfuller(
#     169     x,
#     170     maxlag: int | None = None,
#    (...)
#     174     regresults=False,
#     175 ):
#     176     """
#     177     Augmented Dickey-Fuller unit root test.
#     178
#    (...)
#     261         http://ideas.repec.org/p/qed/wpaper/1227.html
#     262     """
# --> 263     x = array_like(x, "x")
#     264     maxlag = int_like(maxlag, "maxlag", optional=True)
#     265     regression = string_like(
#     266         regression, "regression", options=("c", "ct", "ctt", "n")
#     267     )
#
# File ~/Documents/Learning/Alura/CEAPS/env/lib/python3.12/site-packages/statsmodels/tools/validation/validation.py:143, in array_like(obj, name, dtype, ndim, maxdim, shape, order, contiguous, optional, writeable)
#     141 elif order == "F":
#     142     reqs += ["F"]
# --> 143 arr = np.require(obj, dtype=dtype, requirements=reqs)
#     144 if maxdim is not None:
#     145     if arr.ndim > maxdim:
#
# File ~/Documents/Learning/Alura/CEAPS/env/lib/python3.12/site-packages/numpy/_core/_asarray.py:127, in require(a, dtype, requirements, like)
#     124     order = 'C'
#     125     requirements.remove('C')
# --> 127 arr = array(a, dtype=dtype, order=order, copy=None, subok=subok)
#     129 for prop in requirements:
#     130     if not arr.flags[prop]:
#
# ValueError: could not convert string to float: '2009-04-01'
